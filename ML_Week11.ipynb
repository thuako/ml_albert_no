# %% [markdown]
# # Week 11
# ## AlexNet CIFAR10
# Recall that LeNet with regularization technique, the accuracy was less than 70%

# %%
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''
# Out:
# '\nStep 1:\n'

# %%
# Image preprocessing modules
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
# Out:
# Files already downloaded and verified

# %%
'''
Step 2
'''

class AlexNet(nn.Module) :
    
    def __init__(self, num_class=10) :
        super(AlexNet, self).__init__()
        
        self.conv_layer1 = nn.Sequential(
                nn.Conv2d(3, 96, kernel_size=4),
                nn.ReLU(),
                nn.Conv2d(96, 96, kernel_size=3),
                nn.ReLU()
                )
        self.conv_layer2 = nn.Sequential(
                nn.Conv2d(96, 256, kernel_size=5, padding=2),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=3, stride=2)
                )
        self.conv_layer3 = nn.Sequential(
                nn.Conv2d(256, 384, kernel_size=3, padding=1),
                nn.ReLU(),
                nn.Conv2d(384, 384, kernel_size=3, padding=1),
                nn.ReLU(),
                nn.Conv2d(384, 256, kernel_size=3, padding=1),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=3, stride=2)
                )
        
        self.fc_layer1 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(9216, 4096),
                nn.ReLU(),
                nn.Dropout(),  #p=0.5 by default
                nn.Linear(4096, 4096),
                nn.ReLU(),     #p=0.5 by default
                nn.Linear(4096, 10)
                )
    
    def forward(self, x) :
        output = self.conv_layer1(x)
        output = self.conv_layer2(output)
        output = self.conv_layer3(output)
        output = output.view(-1, 9216)
        output = self.fc_layer1(output)
        return output

# %%
'''
Step 3
'''
model = AlexNet().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-1, weight_decay=0.00005)

# %%
'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=512, shuffle=True)

import time
start = time.time()
for epoch in range(100) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))
# Out:
# 0th epoch starting.
# Epoch [1] Loss: 2.1343
# 1th epoch starting.
# Epoch [2] Loss: 2.2314
# 2th epoch starting.
# Epoch [3] Loss: 2.3183
# 3th epoch starting.
# Epoch [4] Loss: 2.1165
# 4th epoch starting.
# Epoch [5] Loss: 1.9650
# 5th epoch starting.
# Epoch [6] Loss: 1.8769
# 6th epoch starting.
# Epoch [7] Loss: 1.8674
# 7th epoch starting.
# Epoch [8] Loss: 1.8617
# 8th epoch starting.
# Epoch [9] Loss: 1.7723
# 9th epoch starting.
# Epoch [10] Loss: 1.7192
# 10th epoch starting.
# Epoch [11] Loss: 1.8587
# 11th epoch starting.
# Epoch [12] Loss: 1.5871
# 12th epoch starting.
# Epoch [13] Loss: 1.5271
# 13th epoch starting.
# Epoch [14] Loss: 1.5662
# 14th epoch starting.
# Epoch [15] Loss: 1.5363
# 15th epoch starting.
# Epoch [16] Loss: 1.5132
# 16th epoch starting.
# Epoch [17] Loss: 1.5134
# 17th epoch starting.
# Epoch [18] Loss: 1.4969
# 18th epoch starting.
# Epoch [19] Loss: 1.4517
# 19th epoch starting.
# Epoch [20] Loss: 1.3647
# 20th epoch starting.
# Epoch [21] Loss: 1.3468
# 21th epoch starting.
# Epoch [22] Loss: 1.3701
# 22th epoch starting.
# Epoch [23] Loss: 1.4014
# 23th epoch starting.
# Epoch [24] Loss: 1.3685
# 24th epoch starting.
# Epoch [25] Loss: 1.3354
# 25th epoch starting.
# Epoch [26] Loss: 1.3473
# 26th epoch starting.
# Epoch [27] Loss: 1.1451
# 27th epoch starting.
# Epoch [28] Loss: 1.2405
# 28th epoch starting.
# Epoch [29] Loss: 1.1591
# 29th epoch starting.
# Epoch [30] Loss: 1.1960
# 30th epoch starting.
# Epoch [31] Loss: 1.2934
# 31th epoch starting.
# Epoch [32] Loss: 1.0563
# 32th epoch starting.
# Epoch [33] Loss: 1.0103
# 33th epoch starting.
# Epoch [34] Loss: 1.0478
# 34th epoch starting.
# Epoch [35] Loss: 1.0433
# 35th epoch starting.
# Epoch [36] Loss: 0.9602
# 36th epoch starting.
# Epoch [37] Loss: 1.0575
# 37th epoch starting.
# Epoch [38] Loss: 0.8854
# 38th epoch starting.
# Epoch [39] Loss: 0.9834
# 39th epoch starting.
# Epoch [40] Loss: 0.9022
# 40th epoch starting.
# Epoch [41] Loss: 0.8473
# 41th epoch starting.
# Epoch [42] Loss: 0.8815
# 42th epoch starting.
# Epoch [43] Loss: 0.8387
# 43th epoch starting.
# Epoch [44] Loss: 0.7895
# 44th epoch starting.
# Epoch [45] Loss: 0.8400
# 45th epoch starting.
# Epoch [46] Loss: 0.8132
# 46th epoch starting.
# Epoch [47] Loss: 0.7503
# 47th epoch starting.
# Epoch [48] Loss: 0.6930
# 48th epoch starting.
# Epoch [49] Loss: 0.6615
# 49th epoch starting.
# Epoch [50] Loss: 0.7220
# 50th epoch starting.
# Epoch [51] Loss: 0.6446
# 51th epoch starting.
# Epoch [52] Loss: 0.6044
# 52th epoch starting.
# Epoch [53] Loss: 0.5648
# 53th epoch starting.
# Epoch [54] Loss: 0.7345
# 54th epoch starting.
# Epoch [55] Loss: 0.6231
# 55th epoch starting.
# Epoch [56] Loss: 0.5391
# 56th epoch starting.
# Epoch [57] Loss: 0.5514
# 57th epoch starting.
# Epoch [58] Loss: 0.6452
# 58th epoch starting.
# Epoch [59] Loss: 0.6596
# 59th epoch starting.
# Epoch [60] Loss: 0.5879
# 60th epoch starting.
# Epoch [61] Loss: 0.5699
# 61th epoch starting.
# Epoch [62] Loss: 0.5769
# 62th epoch starting.
# Epoch [63] Loss: 0.4631
# 63th epoch starting.
# Epoch [64] Loss: 0.4994
# 64th epoch starting.
# Epoch [65] Loss: 0.4502
# 65th epoch starting.
# Epoch [66] Loss: 0.4209
# 66th epoch starting.
# Epoch [67] Loss: 0.5566
# 67th epoch starting.
# Epoch [68] Loss: 0.4574
# 68th epoch starting.
# Epoch [69] Loss: 0.4696
# 69th epoch starting.
# Epoch [70] Loss: 0.4607
# 70th epoch starting.
# Epoch [71] Loss: 0.5329
# 71th epoch starting.
# Epoch [72] Loss: 0.4990
# 72th epoch starting.
# Epoch [73] Loss: 0.4918
# 73th epoch starting.
# Epoch [74] Loss: 0.4238
# 74th epoch starting.
# Epoch [75] Loss: 0.3362
# 75th epoch starting.
# Epoch [76] Loss: 0.4603
# 76th epoch starting.
# Epoch [77] Loss: 0.3226
# 77th epoch starting.
# Epoch [78] Loss: 0.3619
# 78th epoch starting.
# Epoch [79] Loss: 0.4729
# 79th epoch starting.
# Epoch [80] Loss: 0.2865
# 80th epoch starting.
# Epoch [81] Loss: 0.4423
# 81th epoch starting.
# Epoch [82] Loss: 0.3322
# 82th epoch starting.
# Epoch [83] Loss: 0.3421
# 83th epoch starting.
# Epoch [84] Loss: 0.4160
# 84th epoch starting.
# Epoch [85] Loss: 0.3219
# 85th epoch starting.
# Epoch [86] Loss: 0.3180
# 86th epoch starting.
# Epoch [87] Loss: 0.3333
# 87th epoch starting.
# Epoch [88] Loss: 0.2931
# 88th epoch starting.
# Epoch [89] Loss: 0.2674
# 89th epoch starting.
# Epoch [90] Loss: 0.3162
# 90th epoch starting.
# Epoch [91] Loss: 0.2668
# 91th epoch starting.
# Epoch [92] Loss: 0.2742
# 92th epoch starting.
# Epoch [93] Loss: 0.2459
# 93th epoch starting.
# Epoch [94] Loss: 0.3132
# 94th epoch starting.
# Epoch [95] Loss: 0.2380
# 95th epoch starting.
# Epoch [96] Loss: 0.2399
# 96th epoch starting.
# Epoch [97] Loss: 0.3378
# 97th epoch starting.
# Epoch [98] Loss: 0.2468
# 98th epoch starting.
# Epoch [99] Loss: 0.3234
# 99th epoch starting.
# Epoch [100] Loss: 0.2592
# Time ellapsed in training is: 1736.7829978466034

# %%
'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():  #using context manager
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# [Test set] Average loss: 0.0043, Accuracy: 8609/10000 (86.09%)
